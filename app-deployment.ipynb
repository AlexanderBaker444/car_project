# %%
import dash
import dash_core_components as dcc
import dash_html_components as html
import plotly.graph_objs as go
from dash.dependencies import Input, Output, State
import pandas as pd
import pickle

########### Initiate the app
external_stylesheets = ['https://codepen.io/chriddyp/pen/bWLwgP.css']
app = dash.Dash(__name__, external_stylesheets=external_stylesheets)
server = app.server
app.title='knn'

########### Set up the layout

app.layout = html.Div(children=[
    html.H1('Classification of Iris Flowers'),
    html.Div([
        html.Div([
            html.Div([
                html.H6('Buying'),
                dcc.Slider(
                    id='slider-1',
                    min=0,
                    max=3,
                    step=1,
                    marks={i:str(i) for i in range(0, 3)},
                    value=1
                ),
            html.Br(),
            ], className='four columns'),
            html.Div([
                html.H6('Maint'),
                dcc.Slider(
                    id='slider-2',
                    min=0,
                    max=3,
                    step=1,
                    marks={i:str(i) for i in range(0, 3)},
                    value=1
                ),
            html.Br(),
            ], className='four columns'),
            html.Div([
                html.H6('Doors'),
                dcc.Slider(
                    id='slider-3',
                    min=0,
                    max=3,
                    step=1,
                    marks={i:str(i) for i in range(0, 3)},
                    value=1
                ),
            html.Br(),
            ], className='four columns'),
            html.Div([
                html.H6('Persons'),
                dcc.Slider(
                    id='slider-4',
                    min=0,
                    max=2,
                    step=1,
                    marks={i:str(i) for i in range(0, 2)},
                    value=1
                ),
            html.Br(),
            ], className='four columns'),
            html.Div([
                html.H6('Lug Boot'),
                dcc.Slider(
                    id='slider-5',
                    min=0,
                    max=2,
                    step=1,
                    marks={i:str(i) for i in range(0, 2)},
                    value=1
                ),
            html.Br(),
            ], className='four columns'),
               html.Div([
                html.H6('Safety'),
                dcc.Slider(
                    id='slider-6',
                    min=0,
                    max=2,
                    step=1,
                    marks={i:str(i) for i in range(0, 2)},
                    value=1
                ),
            html.Br(),
            ], className='four columns'),
            
            html.Div([
                html.H6('Model Type'),
                dcc.Dropdown(
                    id='k-drop',
                    options=[{'label': i, 'value': i} for i in [1,2,3,4]],
                    value=1
                ),
            html.Br(),
            ], className='four columns'),
        ], className='twelve columns'),
        html.Div([
            html.H6(id='message'),
        ], className='twelve columns'),
    html.Br(),
    html.A('Code on Github', href='https://github.com/austinlasseter/knn_iris_plotly'),
    ])
])

######### Define Callbacks

@app.callback(Output('message', 'children'),
              [Input('k-drop', 'value'),
               Input('slider-1', 'value'),
               Input('slider-2', 'value'),
               Input('slider-3', 'value'),
              Input('slider-4', 'value'),
              Input('slider-5', 'value'),
              Input('slider-5', 'value')])
def display_results(k, value0, value1,value2,value3,value4,value5):
    # read in the correct model
    file = open(f'model{k}.pkl', 'rb')
    model=pickle.load(file)
    file.close()
    # define the new observation from the slide values
    new_observation=[[value0, value1,value2,value3,value4,value5]]
    prediction=model.predict(new_observation)
    specieslist=['unacc', 'acc', 'good','vgood']
    species_prediction=specieslist[prediction[0]]
    return f'With these attributes, the condition will be {species_prediction}.'


############ Execute the app
if __name__ == '__main__':
    app.run_server()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: Do not use the development server in a production environment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [13/Oct/2019 21:56:02] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Oct/2019 21:56:04] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Oct/2019 21:56:04] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Oct/2019 21:56:06] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Oct/2019 21:56:12] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Oct/2019 21:56:13] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Oct/2019 21:56:17] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Oct/2019 21:56:20] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Oct/2019 21:56:21] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Oct/2019 21:56:22] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Oct/2019 21:56:24] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Oct/2019 21:56:26] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Oct/2019 21:56:29] "POST /_dash-update-component HTTP/1.1" 200 -
# [2019-10-13 21:56:30,154] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\603766\AppData\Local\Continuum\anaconda3\lib\site-packages\flask\app.py", line 2292, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\603766\AppData\Local\Continuum\anaconda3\lib\site-packages\flask\app.py", line 1815, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\603766\AppData\Local\Continuum\anaconda3\lib\site-packages\flask\app.py", line 1718, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\603766\AppData\Local\Continuum\anaconda3\lib\site-packages\flask\_compat.py", line 35, in reraise
#     raise value
#   File "C:\Users\603766\AppData\Local\Continuum\anaconda3\lib\site-packages\flask\app.py", line 1813, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\603766\AppData\Local\Continuum\anaconda3\lib\site-packages\flask\app.py", line 1799, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\603766\AppData\Local\Continuum\anaconda3\lib\site-packages\dash\dash.py", line 1073, in dispatch
#     response.set_data(self.callback_map[output]['callback'](*args))
#   File "C:\Users\603766\AppData\Local\Continuum\anaconda3\lib\site-packages\dash\dash.py", line 969, in add_context
#     output_value = func(*args, **kwargs)
#   File "<ipython-input-1-8b4bd7f10142>", line 124, in display_results
#     file = open(f'model{k}.pkl', 'rb')
# FileNotFoundError: [Errno 2] No such file or directory: 'modelNone.pkl'
# 127.0.0.1 - - [13/Oct/2019 21:56:30] "POST /_dash-update-component HTTP/1.1" 500 -
# 127.0.0.1 - - [13/Oct/2019 21:56:32] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Oct/2019 21:56:37] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Oct/2019 21:56:46] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Oct/2019 21:56:49] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Oct/2019 21:56:51] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Oct/2019 21:56:55] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Oct/2019 21:56:59] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Oct/2019 21:57:01] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Oct/2019 21:57:08] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Oct/2019 21:57:11] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Oct/2019 21:57:15] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Oct/2019 21:57:20] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Oct/2019 21:57:23] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Oct/2019 21:57:26] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Oct/2019 21:57:30] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Oct/2019 21:57:43] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Oct/2019 21:57:47] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Oct/2019 21:57:48] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Oct/2019 21:57:51] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Oct/2019 21:57:53] "POST /_dash-update-component HTTP/1.1" 200 -

# %%
import pickle
def display_results(k, value0, value1,value2,value3,value4,value5):
    # read in the correct model
    file = open(f'model{k}.pkl', 'rb')
    model=pickle.load(file)
    file.close()
    # define the new observation from the slide values
    new_observation=[[value0, value1,value2,value3,value4,value5]]
    prediction=model.predict(new_observation)
    specieslist=['unacc', 'acc', 'good','vgood']
    species_prediction=specieslist[prediction[0]]
    return f'For a flower with sepal length {value0} and{value1} petal length {value2},{value3} the predicted species is.{species_prediction}'

# %%
display_results(1,0, 0, 3, 1, 3, 1)
# Out:
# 'For a flower with sepal length 0 and0 petal length 3,1 the predicted species is.vgood'
